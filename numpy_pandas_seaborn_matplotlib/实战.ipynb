# %%
import pandas_datareader as pdr

# %%
alibaba = pdr.get_data_yahoo('BABA')

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2014-09-19  99.699997  89.949997  92.699997  93.889999  271879400  93.889999
# 2014-09-22  92.949997  89.500000  92.699997  89.889999   66657800  89.889999
# 2014-09-23  90.480003  86.620003  88.940002  87.169998   39009800  87.169998
# 2014-09-24  90.570000  87.220001  88.470001  90.570000   32088000  90.570000
# 2014-09-25  91.500000  88.500000  91.089996  88.919998   28598000  88.919998

# %%
alibaba.shape
# Out:
# (1165, 6)

# %%
alibaba.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-05-01  193.195007  185.880005  186.750000  189.309998  17397500
# 2019-05-02  192.699997  186.649994  189.419998  190.389999  11468100
# 2019-05-03  195.720001  191.880005  191.880005  195.210007  14521100
# 2019-05-06  189.000000  184.830002  185.169998  188.240005  23941200
# 2019-05-07  186.449997  179.630005  186.050003  181.429993  22637700
#
#              Adj Close
# Date
# 2019-05-01  189.309998
# 2019-05-02  190.389999
# 2019-05-03  195.210007
# 2019-05-06  188.240005
# 2019-05-07  181.429993

# %%
alibaba.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1165.000000  1165.000000  1165.000000  1165.000000  1.165000e+03
# mean    125.135540   122.061264   123.704329   123.614592  1.743357e+07
# std      44.813307    43.784197    44.364599    44.323008  1.275442e+07
# min      58.650002    57.200001    57.299999    57.389999  3.775300e+06
# 25%      84.995003    82.970001    84.010002    84.150002  1.088690e+07
# 50%     106.940002   104.209999   105.680000   105.550003  1.472560e+07
# 75%     173.229996   169.610001   171.860001   171.740005  2.021970e+07
# max     211.699997   207.509995   209.949997   210.860001  2.718794e+08
#
#          Adj Close
# count  1165.000000
# mean    123.614592
# std      44.323008
# min      57.389999
# 25%      84.150002
# 50%     105.550003
# 75%     171.740005
# max     210.860001

# %%
alibaba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1165 entries, 2014-09-19 to 2019-05-07
# Data columns (total 6 columns):
# High         1165 non-null float64
# Low          1165 non-null float64
# Open         1165 non-null float64
# Close        1165 non-null float64
# Volume       1165 non-null int64
# Adj Close    1165 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 63.7 KB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pandas import Series,DataFrame
from datetime import datetime

# %matplotlib inline

# %%
alibaba.to_csv("./BABA.csv")

# %%
amazon = pdr.get_data_yahoo('AMZN')

# %%
amazon.to_csv("./AMZN.csv")

# %%
amazon.tail()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-05-01  1943.640015  1910.550049  1933.089966  1911.520020  3117000
# 2019-05-02  1921.550049  1881.869995  1913.329956  1900.819946  3962900
# 2019-05-03  1964.400024  1936.000000  1949.000000  1962.459961  6381600
# 2019-05-06  1959.000000  1910.500000  1917.979980  1950.550049  5417800
# 2019-05-07  1949.099976  1903.380005  1939.989990  1921.000000  5891600
#
#               Adj Close
# Date
# 2019-05-01  1911.520020
# 2019-05-02  1900.819946
# 2019-05-03  1962.459961
# 2019-05-06  1950.550049
# 2019-05-07  1921.000000

# %%
alibaba['Adj Close'].plot(legend=True)

# %%
alibaba['Volume'].plot(legend=True)

# %%
alibaba['Adj Close'].plot(legend=True)
amazon['Adj Close'].plot(legend=True)
sns.set()

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2014-09-19  99.699997  89.949997  92.699997  93.889999  271879400  93.889999
# 2014-09-22  92.949997  89.500000  92.699997  89.889999   66657800  89.889999
# 2014-09-23  90.480003  86.620003  88.940002  87.169998   39009800  87.169998
# 2014-09-24  90.570000  87.220001  88.470001  90.570000   32088000  90.570000
# 2014-09-25  91.500000  88.500000  91.089996  88.919998   28598000  88.919998

# %%
alibaba['high-low'] = alibaba['High']-alibaba['Low']

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close  \
# Date
# 2014-09-19  99.699997  89.949997  92.699997  93.889999  271879400  93.889999
# 2014-09-22  92.949997  89.500000  92.699997  89.889999   66657800  89.889999
# 2014-09-23  90.480003  86.620003  88.940002  87.169998   39009800  87.169998
# 2014-09-24  90.570000  87.220001  88.470001  90.570000   32088000  90.570000
# 2014-09-25  91.500000  88.500000  91.089996  88.919998   28598000  88.919998
#
#             high-low
# Date
# 2014-09-19  9.750000
# 2014-09-22  3.449997
# 2014-09-23  3.860001
# 2014-09-24  3.349998
# 2014-09-25  3.000000

# %%
alibaba['high-low'].plot()

# %%
#daily return
alibaba['daily-return']=alibaba['Adj Close'].pct_change()

# %%
alibaba['daily-return'].plot(figsize=(15,4),linestyle='--',marker='.')

# %%
alibaba['daily-return'].plot(kind="hist")

# %%
sns.distplot(alibaba['daily-return'].dropna(),bins=100,color="purple")

# %%
company = ['AAPL','GOOG','MSFT','AMZN','FB']

# %%
top_tech_df = pdr.get_data_yahoo(company)['Adj Close']

# %%
top_tech_df.to_csv('./top5.csv')

# %%
amazon.tail()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-05-01  1943.640015  1910.550049  1933.089966  1911.520020  3117000
# 2019-05-02  1921.550049  1881.869995  1913.329956  1900.819946  3962900
# 2019-05-03  1964.400024  1936.000000  1949.000000  1962.459961  6381600
# 2019-05-06  1959.000000  1910.500000  1917.979980  1950.550049  5417800
# 2019-05-07  1949.099976  1903.380005  1939.989990  1921.000000  5891600
#
#               Adj Close
# Date
# 2019-05-01  1911.520020
# 2019-05-02  1900.819946
# 2019-05-03  1962.459961
# 2019-05-06  1950.550049
# 2019-05-07  1921.000000

# %%
amazon.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2009-12-31  137.279999  134.520004  137.089996  134.520004   4523000
# 2010-01-04  136.610001  133.139999  136.250000  133.899994   7599900
# 2010-01-05  135.479996  131.809998  133.429993  134.690002   8851900
# 2010-01-06  134.729996  131.649994  134.600006  132.250000   7178800
# 2010-01-07  132.320007  128.800003  132.009995  130.000000  11030200
#
#              Adj Close
# Date
# 2009-12-31  134.520004
# 2010-01-04  133.899994
# 2010-01-05  134.690002
# 2010-01-06  132.250000
# 2010-01-07  130.000000

# %%
top_tech_df.head()
# Out:
# Symbols          AAPL        AMZN  FB        GOOG       MSFT
# Date
# 2009-12-31  20.073631  134.520004 NaN  307.986847  24.241983
# 2010-01-04  20.386072  133.899994 NaN  311.349976  24.615801
# 2010-01-05  20.421322  134.690002 NaN  309.978882  24.623755
# 2010-01-06  20.096491  132.250000 NaN  302.164703  24.472631
# 2010-01-07  20.059338  130.000000 NaN  295.130463  24.218124

# %%
top_tech_dr = top_tech_df.pct_change()

# %%
top_tech_dr.head()
# Out:
# Symbols         AAPL      AMZN  FB      GOOG      MSFT
# Date
# 2009-12-31       NaN       NaN NaN       NaN       NaN
# 2010-01-04  0.015565 -0.004609 NaN  0.010920  0.015420
# 2010-01-05  0.001729  0.005900 NaN -0.004404  0.000323
# 2010-01-06 -0.015906 -0.018116 NaN -0.025209 -0.006137
# 2010-01-07 -0.001849 -0.017013 NaN -0.023279 -0.010400

# %%
top_tech_df.plot(figsize=(10,5))

# %%
top_tech_df[['AAPL','FB','MSFT']].plot(figsize=(10,5))

# %%
sns.jointplot('AMZN','GOOG',top_tech_dr,kind="scatter")

# %%
sns.jointplot('MSFT','FB',top_tech_dr,kind="scatter")

# %%
sns.pairplot(top_tech_dr.dropna())

# %%
top_tech_dr['AAPL'].quantile(0.52)
# Out:
# -0.025049675709770014

# %%
top_tech_dr['MSFT'].quantile(0.05)
# Out:
# -0.021145540921220618

# %%
vips = pdr.get_data_yahoo('VIPS')["Adj Close"]

# %%
vips.plot(figsize=(10,5))

# %%
vips.pct_change().quantile(0.2)
# Out:
# -0.022860346959082966
