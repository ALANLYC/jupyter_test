# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series,DataFrame

# %%
s1 = Series(np.random.randn(1000).cumsum())
s2 = Series(np.random.randn(1000).cumsum())

# %%
s = Series([1,2,3,4,5])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.cumsum()  #求累加和
# Out:
# 0     1
# 1     3
# 2     6
# 3    10
# 4    15
# dtype: int64

# %%
s1.plot

# %%
# %matplotlib inline

# %%
#''''''
#s1.plot(
#    kind='line',
 #   ax=None,
 #   figsize=None,
 #   use_index=True,
 #   title=None,
 #   grid=None,
 #   legend=False,
#    style=None,
#''''''



s1.plot(kind = 'line',grid=True,label = 's1',title = 'Series',style = 'y--')
s2.plot(kind = 'line',grid=True,label = 's2',title = 'Series',style = 'y--')
plt.legend()

# %%
fig,ax = plt.subplots(2,1)
ax[0].plot(s1)
ax[1].plot(s2)

# %%
fig,ax = plt.subplots(2,1)
s1[0:10].plot(ax=ax[0],label='s1',kind='bar')
s2.plot(ax=ax[1],label = 's2')

# %% [markdown]
# # Pandas绘图之Series

# %%
df = DataFrame(
    np.random.randint(1,10,40).reshape(10,4),
    columns=('A','B','C','D')
   
)

# %%
df
# Out:
#    A  B  C  D
# 0  4  7  5  9
# 1  5  7  1  2
# 2  4  2  1  1
# 3  7  7  6  6
# 4  3  1  8  2
# 5  2  6  2  8
# 6  9  1  2  9
# 7  7  3  3  3
# 8  5  6  1  3
# 9  7  3  5  7

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh')

# %%
df.plot(kind='bar',stacked = True)

# %%
df.plot(kind='area')

# %%
a = df.iloc[5].plot()

# %%
for i in df.index:
    df.iloc[i].plot(label=str(i))
plt.legend()

# %%
df['A'].plot()

# %%
df.T.plot()
